# %% [markdown]
# # Iris Dataset — Data Cleaning & Exploratory Data Analysis
#
# ## Overview
#
# This project focuses on cleaning and exploring the Iris dataset using Python. The workflow covers data loading, data quality checks, missing-value treatment, duplicate and garbage-value checks, exploratory data analysis, outlier treatment, and data transformation.
#
# ## Objectives
#
# - Understand the structure and quality of the dataset
# - Identify missing values, duplicates, and inconsistent values
# - Explore numerical feature distributions and relationships
# - Detect and treat outliers
# - Prepare the dataset for further analysis or machine learning

# %% [markdown]
# ## 1. Import Libraries
#
# Import the required Python libraries for data manipulation, numerical analysis, visualization, and exploratory data analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Load and Inspect the Dataset
#
# Load the Iris dataset and perform initial sanity checks to understand its structure, dimensions, data types, and sample records.

# %%
df=pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## 3. Data Quality Checks
#
# Check the dataset for missing values, duplicate records, and potential garbage or inconsistent values.

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
#percentage of values
df.isnull().sum()/df.shape[0]*100
# Out:
# SepalLengthCm    0.0
# SepalWidthCm     0.0
# PetalLengthCm    0.0
# PetalWidthCm     0.0
# Species          0.0
# dtype: float64

# %%
#finding duplicates
df.duplicated().sum()
# Out:
# np.int64(3)

# %%
#identifying  garbage values
for i in df.select_dtypes(include="object").columns:
    print(df[i].value_counts())
    print("****")
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64
# ****

# %% [markdown]
# ## 4. Exploratory Data Analysis
#
# Perform exploratory analysis to understand feature distributions, identify potential outliers, and examine relationships between numerical variables.

# %%
#descriptive statistics
df.describe().T
# Out:
#                count      mean       std  min  25%   50%  75%  max
# SepalLengthCm  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# SepalWidthCm   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# PetalLengthCm  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# PetalWidthCm   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %%
df.describe(include="object")
# Out:
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %%
#histogram to understand the distribution
for i in df.select_dtypes(include="number").columns:
    sns.histplot(data=df,x=i)
    plt.show()

# %%
#boxplot to identify outliers
for i in df.select_dtypes(include="number").columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %%
#scatter plot to understand the relationship
for i in ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']:
    sns.scatterplot(data=df,x=i,y='Species')
    plt.show()

# %%
#correlation with heat ap to interpret the relaton and mulicollinarity
s=df.select_dtypes(include="number").corr()

# %%
plt.figure(figsize=(5,5))
sns.heatmap(s,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## 5. Missing Value Treatment
#
# Identify missing values and apply numerical imputation to prepare the dataset for further analysis.

# %%
#missing values treatmeants
#like mean, median, mode or knniputer
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
for i in ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']:
    df[i] = df[i].fillna(df[i].median())
    # in place we have to fill mode,mean means chnge median to mean or mode

# %% [markdown]
# ## KNNImputer

# %%
from sklearn.impute import KNNImputer
impute=KNNImputer()

# %%
from sklearn.impute import SimpleImputer

impute = SimpleImputer(strategy='mean')

num_cols = df.select_dtypes(include='number').columns

df[num_cols] = impute.fit_transform(df[num_cols])
print(df[num_cols])
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ## 6. Outlier Detection and Treatment
#
# Use the Interquartile Range (IQR) method to identify potential outliers and apply a capping approach to the SepalWidthCm feature.

# %%
#decide whether to do outliers treatment or not, if do how?
def wisker(col):
    q1,q3=np.percentile(col,[25,75])
    iqr=q3-q1
    lw=q1-1.5*iqr
    uw=q3+1.5*iqr
    return lw,uw

# %%
wisker(df['SepalWidthCm'])
# Out:
# (np.float64(2.05), np.float64(4.05))

# %%
for i in ['SepalWidthCm']:
    lw,uw=wisker(df[i])
    df[i]=np.where(df[i]<lw,lw,df[i])
    df[i]=np.where(df[i]>uw,uw,df[i])

# %%
for i in ['SepalWidthCm']:
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# ## 7. Duplicate Record Handling
#
# Check for duplicate records and remove duplicate observations from the dataset.

# %%
#drop duplicates
df.drop_duplicates()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %% [markdown]
# ## 8. Data Transformation
#
# Apply encoding techniques to transform categorical information into a machine-readable format.

# %%
#encoding data
dummy=pd.get_dummies(data=df,columns=['SepalLengthCm', 'SepalWidthCm'],drop_first=True)

# %%
dummy
# Out:
#      PetalLengthCm  PetalWidthCm         Species  SepalLengthCm_4.4  \
# 0              1.4           0.2     Iris-setosa              False
# 1              1.4           0.2     Iris-setosa              False
# 2              1.3           0.2     Iris-setosa              False
# 3              1.5           0.2     Iris-setosa              False
# 4              1.4           0.2     Iris-setosa              False
# ..             ...           ...             ...                ...
# 145            5.2           2.3  Iris-virginica              False
# 146            5.0           1.9  Iris-virginica              False
# 147            5.2           2.0  Iris-virginica              False
# 148            5.4           2.3  Iris-virginica              False
# 149            5.1           1.8  Iris-virginica              False
#
#      SepalLengthCm_4.5  SepalLengthCm_4.6  SepalLengthCm_4.7  \
# 0                False              False              False
# ...

# %% [markdown]
# ## Conclusion
#
# The Iris dataset was examined through a complete data preprocessing and exploratory analysis workflow. Missing values, duplicates, potential garbage values, and outliers were investigated and addressed. Statistical summaries and visualizations were used to understand feature distributions and relationships, providing a cleaned dataset suitable for further analysis or machine learning.
